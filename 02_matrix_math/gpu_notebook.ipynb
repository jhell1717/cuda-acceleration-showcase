# %%
# !git clone https://github.com/jhell1717/cuda-acceleration-showcase.git

# %%
import sys
import os
import time

# Add the directory containing the modules to the Python path
module_path = '/content/cuda-acceleration-showcase/01_matrix_math'
if module_path not in sys.path:
    sys.path.append(module_path)

print(f"Added {module_path} to sys.path")

# %%
from cpu_matrix import cpu_matrix_multiply
from gpu_matrix import gpu_matrix_multiply
import numpy as np
import time

# %%
A = np.random.rand(10000,10000)
B = np.random.rand(10000,10000)

# %timeit cpu_result = cpu_matrix_multiply(A,B)
# Out:
# 5.58 s ± 152 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Out:
# array([[0.78745186, 0.96306045, 0.66579312, 0.17433928, 0.7854947 ],
#        [0.25686769, 0.59616522, 0.24980527, 0.64118891, 0.02718947],
#        [0.12099191, 0.48091955, 0.8335059 , 0.38998148, 0.28482209],
#        [0.28528481, 0.19428781, 0.28539793, 0.31992015, 0.27575231],
#        [0.07879726, 0.20384814, 0.09615306, 0.17824272, 0.54734109]])
