# %%
import cv2
from cpu_gaussian_blur import load_image, cpu_gaussian_blur
from gpu_gaussian_blur import gpu_gaussian_blur

# %%
img_path = r"/Users/joshuahellewell/Desktop/01-dev/cuda-acceleration-showcase/data/tiger.jpg"

# %%
img = load_image(img_path,grayscale=True)

# %%
blurred_image = cpu_gaussian_blur(img,sigma=3)
cv2.imwrite("blurred_image.jpg",blurred_image)
# Out:
# True

# %%
blur = gpu_gaussian_blur(img)
# Out:
# ---------------------------------------------------------------------------
# CudaSupportError                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 blur = gpu_gaussian_blur(img)
#
# File ~/Desktop/01-dev/cuda-acceleration-showcase/01_image_processing/gpu_gaussian_blur.py:39, in gpu_gaussian_blur(img)
#      36 def gpu_gaussian_blur(img):
#      37     img = img.astype(np.float32)
# ---> 39     d_input = cuda.to_device(img)
#      40     d_output = cuda.device_array_like(img)
#      41     d_kernel = cuda.to_device(GAUSSIAN_KERNEL)
#
# File ~/Desktop/01-dev/cuda-acceleration-showcase/.conda/lib/python3.11/site-packages/numba/cuda/cudadrv/devices.py:231, in require_context.<locals>._require_cuda_context(*args, **kws)
#     229 @functools.wraps(fn)
#     230 def _require_cuda_context(*args, **kws):
# --> 231     with _runtime.ensure_context():
#     232         return fn(*args, **kws)
#
# ...
